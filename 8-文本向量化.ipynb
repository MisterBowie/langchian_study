# %%
import os
import os
from dotenv import load_dotenv
# Load environment variables from openai.env file
load_dotenv("openai.env")

# Read the OPENAI_API_KEY from the environment
api_key = os.getenv("OPENAI_API_KEY")
api_base = os.getenv("OPENAI_API_BASE")
os.environ["OPENAI_API_KEY"] = api_key
os.environ["OPENAI_API_BASE"] = api_base
print(os.environ["OPENAI_API_KEY"])
print(os.environ["OPENAI_API_BASE"])
# res = openai.ChatCompletion.create(
#     model="gpt-3.5-turbo",
#     messages=messages,
#     stream=False
# )
# print(res['choices'][0]['message']['content'])
# Out:
# sk-M2NQLaQ3rDPK16EEGBi5QfUivICizJ641qh6B7elXulzJuUS
# https://api.openai-proxy.org/v1

# %%
! pip install --upgrade langchain
! pip install --upgrade openai==0.27.8
! pip install -U langchain-openai
# Out:
# Requirement already satisfied: langchain in ./myenv/lib/python3.10/site-packages (0.3.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in ./myenv/lib/python3.10/site-packages (from langchain) (2.10.3)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in ./myenv/lib/python3.10/site-packages (from langchain) (0.1.147)
# Requirement already satisfied: numpy<2,>=1.22.4 in ./myenv/lib/python3.10/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in ./myenv/lib/python3.10/site-packages (from langchain) (0.3.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in ./myenv/lib/python3.10/site-packages (from langchain) (3.11.10)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in ./myenv/lib/python3.10/site-packages (from langchain) (8.5.0)
# Requirement already satisfied: requests<3,>=2 in ./myenv/lib/python3.10/site-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in ./myenv/lib/python3.10/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in ./myenv/lib/python3.10/site-packages (from langchain) (0.3.21)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in ./myenv/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in ./myenv/lib/python3.10/site-packages (from langchain) (2.0.36)
# Requirement already satisfied: attrs>=17.3.0 in ./myenv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./myenv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in ./myenv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./myenv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.4)
# Requirement already satisfied: propcache>=0.2.0 in ./myenv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (0.2.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./myenv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./myenv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.18.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./myenv/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./myenv/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in ./myenv/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain) (4.12.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./myenv/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.12)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./myenv/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./myenv/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./myenv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in ./myenv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./myenv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./myenv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in ./myenv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./myenv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in ./myenv/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: httpcore==1.* in ./myenv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.7)
# Requirement already satisfied: anyio in ./myenv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.7.0)
# Requirement already satisfied: h11<0.15,>=0.13 in ./myenv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./myenv/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.21->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in ./myenv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./myenv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# Collecting openai==0.27.8
#   Using cached openai-0.27.8-py3-none-any.whl (73 kB)
# Requirement already satisfied: requests>=2.20 in ./myenv/lib/python3.10/site-packages (from openai==0.27.8) (2.32.3)
# Requirement already satisfied: tqdm in ./myenv/lib/python3.10/site-packages (from openai==0.27.8) (4.67.1)
# Requirement already satisfied: aiohttp in ./myenv/lib/python3.10/site-packages (from openai==0.27.8) (3.11.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./myenv/lib/python3.10/site-packages (from requests>=2.20->openai==0.27.8) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in ./myenv/lib/python3.10/site-packages (from requests>=2.20->openai==0.27.8) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./myenv/lib/python3.10/site-packages (from requests>=2.20->openai==0.27.8) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./myenv/lib/python3.10/site-packages (from requests>=2.20->openai==0.27.8) (3.4.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in ./myenv/lib/python3.10/site-packages (from aiohttp->openai==0.27.8) (1.18.3)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in ./myenv/lib/python3.10/site-packages (from aiohttp->openai==0.27.8) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in ./myenv/lib/python3.10/site-packages (from aiohttp->openai==0.27.8) (1.5.0)
# Requirement already satisfied: attrs>=17.3.0 in ./myenv/lib/python3.10/site-packages (from aiohttp->openai==0.27.8) (24.2.0)
# Requirement already satisfied: propcache>=0.2.0 in ./myenv/lib/python3.10/site-packages (from aiohttp->openai==0.27.8) (0.2.1)
# Requirement already satisfied: aiosignal>=1.1.2 in ./myenv/lib/python3.10/site-packages (from aiohttp->openai==0.27.8) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./myenv/lib/python3.10/site-packages (from aiohttp->openai==0.27.8) (6.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in ./myenv/lib/python3.10/site-packages (from aiohttp->openai==0.27.8) (2.4.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in ./myenv/lib/python3.10/site-packages (from multidict<7.0,>=4.5->aiohttp->openai==0.27.8) (4.12.2)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.57.0
#     Uninstalling openai-1.57.0:
#       Successfully uninstalled openai-1.57.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.2.11 requires openai<2.0.0,>=1.54.0, but you have openai 0.27.8 which is incompatible.
# Successfully installed openai-0.27.8
# Requirement already satisfied: langchain-openai in ./myenv/lib/python3.10/site-packages (0.2.11)
# Requirement already satisfied: tiktoken<1,>=0.7 in ./myenv/lib/python3.10/site-packages (from langchain-openai) (0.8.0)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in ./myenv/lib/python3.10/site-packages (from langchain-openai) (0.3.21)
# Collecting openai<2.0.0,>=1.54.0
#   Using cached openai-1.57.0-py3-none-any.whl (389 kB)
# Requirement already satisfied: typing-extensions>=4.7 in ./myenv/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (4.12.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in ./myenv/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (0.1.147)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in ./myenv/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (8.5.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in ./myenv/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (2.10.3)
# Requirement already satisfied: PyYAML>=5.3 in ./myenv/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in ./myenv/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in ./myenv/lib/python3.10/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai) (23.2)
# Requirement already satisfied: sniffio in ./myenv/lib/python3.10/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (1.3.1)
# Requirement already satisfied: distro<2,>=1.7.0 in ./myenv/lib/python3.10/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (1.9.0)
# Requirement already satisfied: tqdm>4 in ./myenv/lib/python3.10/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (4.67.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in ./myenv/lib/python3.10/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (4.7.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in ./myenv/lib/python3.10/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (0.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./myenv/lib/python3.10/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (0.28.1)
# Requirement already satisfied: requests>=2.26.0 in ./myenv/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.3)
# Requirement already satisfied: regex>=2022.1.18 in ./myenv/lib/python3.10/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.11.6)
# Requirement already satisfied: idna>=2.8 in ./myenv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.54.0->langchain-openai) (3.10)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./myenv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.54.0->langchain-openai) (1.2.2)
# Requirement already satisfied: certifi in ./myenv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain-openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in ./myenv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain-openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in ./myenv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.54.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in ./myenv/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.21->langchain-openai) (3.0.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in ./myenv/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.21->langchain-openai) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in ./myenv/lib/python3.10/site-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.21->langchain-openai) (3.10.12)
# Requirement already satisfied: annotated-types>=0.6.0 in ./myenv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.21->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in ./myenv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.21->langchain-openai) (2.27.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./myenv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./myenv/lib/python3.10/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (3.4.0)
# Installing collected packages: openai
#   Attempting uninstall: openai
#     Found existing installation: openai 0.27.8
#     Uninstalling openai-0.27.8:
#       Successfully uninstalled openai-0.27.8
# Successfully installed openai-1.57.0

# %%
from langchain_openai import OpenAIEmbeddings

e_model = OpenAIEmbeddings()
ebeddings = e_model.embed_documents(
     [
        "你好",
        "你好啊",
        "你叫什么名字?",
        "我叫王大锤",
        "很高兴认识你大锤",
    ]
)
ebeddings
# Out:
# ---------------------------------------------------------------------------
# ProxyError                                Traceback (most recent call last)
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpcore/_sync/http_proxy.py:297, in TunnelHTTPConnection.handle_request(self, request)
#     296     self._connection.close()
# --> 297     raise ProxyError(msg)
#     299 stream = connect_response.extensions["network_stream"]
#
# ProxyError: 405 Method Not Allowed
#
# The above exception was the direct cause of the following exception:
#
# ProxyError                                Traceback (most recent call last)
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:993, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     992 try:
# --> 993     response = self._client.send(
#     994         request,
#     995         stream=stream or self._should_stream_response_body(request=request),
#     996         **kwargs,
#     997     )
#     998 except httpx.TimeoutException as err:
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File ~/.pyenv/versions/3.10.5/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ProxyError: 405 Method Not Allowed
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[8], line 4
#       1 from langchain_openai import OpenAIEmbeddings
#       3 e_model = OpenAIEmbeddings()
# ----> 4 ebeddings = e_model.embed_documents(
#       5      [
#       6         "你好",
#       7         "你好啊",
#       8         "你叫什么名字?",
#       9         "我叫王大锤",
#      10         "很高兴认识你大锤",
#      11     ]
#      12 )
#      13 ebeddings
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/langchain_openai/embeddings/base.py:588, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     585 # NOTE: to keep things simple, we assume the list may contain texts longer
#     586 #       than the maximum context and use length-safe embedding function.
#     587 engine = cast(str, self.deployment)
# --> 588 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/langchain_openai/embeddings/base.py:483, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     481 batched_embeddings: List[List[float]] = []
#     482 for i in _iter:
# --> 483     response = self.client.create(
#     484         input=tokens[i : i + _chunk_size], **self._invocation_params
#     485     )
#     486     if not isinstance(response, dict):
#     487         response = response.model_dump()
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/resources/embeddings.py:124, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     118         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     119             base64.b64decode(data), dtype="float32"
#     120         ).tolist()
#     122     return obj
# --> 124 return self._post(
#     125     "/embeddings",
#     126     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     127     options=make_request_options(
#     128         extra_headers=extra_headers,
#     129         extra_query=extra_query,
#     130         extra_body=extra_body,
#     131         timeout=timeout,
#     132         post_parser=parser,
#     133     ),
#     134     cast_to=CreateEmbeddingResponse,
#     135 )
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:1280, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1266 def post(
#    1267     self,
#    1268     path: str,
#    (...)
#    1275     stream_cls: type[_StreamT] | None = None,
#    1276 ) -> ResponseT | _StreamT:
#    1277     opts = FinalRequestOptions.construct(
#    1278         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1279     )
# -> 1280     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:957, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     954 else:
#     955     retries_taken = 0
# --> 957 return self._request(
#     958     cast_to=cast_to,
#     959     options=options,
#     960     stream=stream,
#     961     stream_cls=stream_cls,
#     962     retries_taken=retries_taken,
#     963 )
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:1017, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1014 log.debug("Encountered Exception", exc_info=True)
#    1016 if remaining_retries > 0:
# -> 1017     return self._retry_request(
#    1018         input_options,
#    1019         cast_to,
#    1020         retries_taken=retries_taken,
#    1021         stream=stream,
#    1022         stream_cls=stream_cls,
#    1023         response_headers=None,
#    1024     )
#    1026 log.debug("Raising connection error")
#    1027 raise APIConnectionError(request=request) from err
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:1017, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1014 log.debug("Encountered Exception", exc_info=True)
#    1016 if remaining_retries > 0:
# -> 1017     return self._retry_request(
#    1018         input_options,
#    1019         cast_to,
#    1020         retries_taken=retries_taken,
#    1021         stream=stream,
#    1022         stream_cls=stream_cls,
#    1023         response_headers=None,
#    1024     )
#    1026 log.debug("Raising connection error")
#    1027 raise APIConnectionError(request=request) from err
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:1027, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1017         return self._retry_request(
#    1018             input_options,
#    1019             cast_to,
#    (...)
#    1023             response_headers=None,
#    1024         )
#    1026     log.debug("Raising connection error")
# -> 1027     raise APIConnectionError(request=request) from err
#    1029 log.debug(
#    1030     'HTTP Response: %s %s "%i %s" %s',
#    1031     request.method,
#    (...)
#    1035     response.headers,
#    1036 )
#    1037 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.

# %% [markdown]
# ### embed_query

# %%
e_model_query =e_model.embed_query("这段话中yinyin的词是？")

print(e_model_query[:5])
# Out:
# ---------------------------------------------------------------------------
# ProxyError                                Traceback (most recent call last)
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpcore/_sync/http_proxy.py:297, in TunnelHTTPConnection.handle_request(self, request)
#     296     self._connection.close()
# --> 297     raise ProxyError(msg)
#     299 stream = connect_response.extensions["network_stream"]
#
# ProxyError: 405 Method Not Allowed
#
# The above exception was the direct cause of the following exception:
#
# ProxyError                                Traceback (most recent call last)
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:993, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#     992 try:
# --> 993     response = self._client.send(
#     994         request,
#     995         stream=stream or self._should_stream_response_body(request=request),
#     996         **kwargs,
#     997     )
#     998 except httpx.TimeoutException as err:
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_transports/default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)
#     247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File ~/.pyenv/versions/3.10.5/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/httpx/_transports/default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ProxyError: 405 Method Not Allowed
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 e_model_query =e_model.embed_query("这段话中yinyin的词是？")
#       3 print(e_model_query[:5])
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/langchain_openai/embeddings/base.py:629, in OpenAIEmbeddings.embed_query(self, text)
#     620 def embed_query(self, text: str) -> List[float]:
#     621     """Call out to OpenAI's embedding endpoint for embedding query text.
#     622
#     623     Args:
#    (...)
#     627         Embedding for the text.
#     628     """
# --> 629     return self.embed_documents([text])[0]
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/langchain_openai/embeddings/base.py:588, in OpenAIEmbeddings.embed_documents(self, texts, chunk_size)
#     585 # NOTE: to keep things simple, we assume the list may contain texts longer
#     586 #       than the maximum context and use length-safe embedding function.
#     587 engine = cast(str, self.deployment)
# --> 588 return self._get_len_safe_embeddings(texts, engine=engine)
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/langchain_openai/embeddings/base.py:483, in OpenAIEmbeddings._get_len_safe_embeddings(self, texts, engine, chunk_size)
#     481 batched_embeddings: List[List[float]] = []
#     482 for i in _iter:
# --> 483     response = self.client.create(
#     484         input=tokens[i : i + _chunk_size], **self._invocation_params
#     485     )
#     486     if not isinstance(response, dict):
#     487         response = response.model_dump()
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/resources/embeddings.py:124, in Embeddings.create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     118         embedding.embedding = np.frombuffer(  # type: ignore[no-untyped-call]
#     119             base64.b64decode(data), dtype="float32"
#     120         ).tolist()
#     122     return obj
# --> 124 return self._post(
#     125     "/embeddings",
#     126     body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#     127     options=make_request_options(
#     128         extra_headers=extra_headers,
#     129         extra_query=extra_query,
#     130         extra_body=extra_body,
#     131         timeout=timeout,
#     132         post_parser=parser,
#     133     ),
#     134     cast_to=CreateEmbeddingResponse,
#     135 )
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:1280, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1266 def post(
#    1267     self,
#    1268     path: str,
#    (...)
#    1275     stream_cls: type[_StreamT] | None = None,
#    1276 ) -> ResponseT | _StreamT:
#    1277     opts = FinalRequestOptions.construct(
#    1278         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1279     )
# -> 1280     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:957, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     954 else:
#     955     retries_taken = 0
# --> 957 return self._request(
#     958     cast_to=cast_to,
#     959     options=options,
#     960     stream=stream,
#     961     stream_cls=stream_cls,
#     962     retries_taken=retries_taken,
#     963 )
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:1017, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1014 log.debug("Encountered Exception", exc_info=True)
#    1016 if remaining_retries > 0:
# -> 1017     return self._retry_request(
#    1018         input_options,
#    1019         cast_to,
#    1020         retries_taken=retries_taken,
#    1021         stream=stream,
#    1022         stream_cls=stream_cls,
#    1023         response_headers=None,
#    1024     )
#    1026 log.debug("Raising connection error")
#    1027 raise APIConnectionError(request=request) from err
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:1017, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1014 log.debug("Encountered Exception", exc_info=True)
#    1016 if remaining_retries > 0:
# -> 1017     return self._retry_request(
#    1018         input_options,
#    1019         cast_to,
#    1020         retries_taken=retries_taken,
#    1021         stream=stream,
#    1022         stream_cls=stream_cls,
#    1023         response_headers=None,
#    1024     )
#    1026 log.debug("Raising connection error")
#    1027 raise APIConnectionError(request=request) from err
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:1095, in SyncAPIClient._retry_request(self, options, cast_to, retries_taken, response_headers, stream, stream_cls)
#    1091 # In a synchronous context we are blocking the entire thread. Up to the library user to run the client in a
#    1092 # different thread if necessary.
#    1093 time.sleep(timeout)
# -> 1095 return self._request(
#    1096     options=options,
#    1097     cast_to=cast_to,
#    1098     retries_taken=retries_taken + 1,
#    1099     stream=stream,
#    1100     stream_cls=stream_cls,
#    1101 )
#
# File ~/person/study/langchain/myenv/lib/python3.10/site-packages/openai/_base_client.py:1027, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1017         return self._retry_request(
#    1018             input_options,
#    1019             cast_to,
#    (...)
#    1023             response_headers=None,
#    1024         )
#    1026     log.debug("Raising connection error")
# -> 1027     raise APIConnectionError(request=request) from err
#    1029 log.debug(
#    1030     'HTTP Response: %s %s "%i %s" %s',
#    1031     request.method,
#    (...)
#    1035     response.headers,
#    1036 )
#    1037 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.

# %% [markdown]
# ### 嵌入向量缓存

# %%
from langchain.embeddings import CacheBackedEmbeddings
from langchain.storage import LocalFileStore
from langchain.document_loaders import TextLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain_openai import OpenAIEmbeddings
u_embeddings = OpenAIEmbeddings()

fs = LocalFileStore("./cache/")

cached_embeddings = CacheBackedEmbeddings.from_bytes_store(
    u_embeddings,
    fs,
    namespace=u_embeddings.model
)
list(fs.yield_keys())
# Out:
# []
